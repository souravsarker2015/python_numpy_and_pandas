# %% [markdown]
# ### pandas
# data
# * open source python package
#
# * cleaning
# * manipulation
# * exploration
# * analysis
#
# * used in data science and machine learning

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### dataframe

# %%
data = {
    "students": ['vikram', 'sajal', 'tito'],
    "scores": [80, 40, 30],
}
print(pd.DataFrame(data))
# Out:
#   students  scores
# 0   vikram      80
# 1    sajal      40
# 2     tito      30

# %%
df = pd.DataFrame(data)

# %%
df['scores'].min()
# Out:
# 30

# %%
df['scores'].max()
# Out:
# 80

# %%
x = [1, 2, 3, 4, 5]
print(pd.Series(x))
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
x = [1, 2, 3, 4, 5]
pd.Series(x, index=['a', 'b', 'c', 'd', 'e'])
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
x = {
    'a': 1,
    'b': 2,
    'c': 3,
    'd': 4,
    'e': 5,
}
pd.Series(x, index=['a', 'b', 'c', 'd'])
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
data = {
    "students": ['vikram', 'sajal', 'tito'],
    "scores": [80, 40, 30],
}

f = pd.DataFrame(data)

# %%
f
# Out:
#   students  scores
# 0   vikram      80
# 1    sajal      40
# 2     tito      30

# %%
f.loc[0]
# Out:
# students    vikram
# scores          80
# Name: 0, dtype: object

# %%
f.loc[[0, 2]]
# Out:
#   students  scores
# 0   vikram      80
# 2     tito      30

# %%
f = pd.read_csv('data/sales_data.csv')

# %%
f
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
f.head(5)
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 0       Offline              H  5/28/2010  669165933  6/27/2010        9925
# 1        Online              C  8/22/2012  963881480  9/15/2012        2804
# 2       Offline              L   5/2/2014  341417157   5/8/2014        1779
# 3        Online              C  6/20/2014  514321792   7/5/2014        8102
# 4       Offline              L   2/1/2013  115456712   2/6/2013        5062
#
# ...

# %%
f.tail(5)
# Out:
#                 Region       Country      Item Type Sales Channel  \
# 95  Sub-Saharan Africa          Mali        Clothes        Online
# 96                Asia      Malaysia         Fruits       Offline
# 97  Sub-Saharan Africa  Sierra Leone     Vegetables       Offline
# 98       North America        Mexico  Personal Care       Offline
# 99  Sub-Saharan Africa    Mozambique      Household       Offline
#
#    Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 95              M   7/26/2011  512878119    9/3/2011         888      109.28
# 96              L  11/11/2011  810711038  12/28/2011        6267        9.33
# 97              C    6/1/2016  728815257   6/29/2016        1485      154.06
# 98              M   7/30/2015  559427106    8/8/2015        5767       81.73
# 99              L   2/10/2012  665095412   2/15/2012        5367      668.27
#
#     Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item Type       100 non-null    object
#  3   Sales Channel   100 non-null    object
#  4   Order Priority  100 non-null    object
#  5   Order Date      100 non-null    object
#  6   Order ID        100 non-null    int64
#  7   Ship Date       100 non-null    object
#  8   Units Sold      100 non-null    int64
#  9   Unit Price      99 non-null     float64
#  10  Unit Cost       100 non-null    float64
#  11  Total Revenue   100 non-null    float64
#  12  Total Cost      100 non-null    float64
#  13  Total Profit    100 non-null    float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 11.1+ KB

# %%
df = pd.DataFrame(f)

# %%
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
country = ['Russia']

# %%
df['Country'].isin(country)
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: Country, Length: 100, dtype: bool

# %%
df[df['Country'].isin(country)]
# Out:
#    Region Country        Item Type Sales Channel Order Priority Order Date  \
# 2  Europe  Russia  Office Supplies       Offline              L   5/2/2014
#
#     Order ID Ship Date  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# 2  341417157  5/8/2014        1779      651.21     524.96     1158502.59
#
#    Total Cost  Total Profit
# 2   933903.84     224598.75

# %%
df['Unit Price'].mean()
# Out:
# 276.97828282828283

# %%
df['Unit Price'].mode()
# Out:
# 0    109.28
# 1    437.20
# Name: Unit Price, dtype: float64

# %%
df['Unit Cost'].median()
# Out:
# 107.275

# %%
df['Unit Cost'].sum(skipna=True)  # skip non available number
# Out:
# 19104.8

# %%
df.mean(axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df.mean(axis=1)
#
# File ~/officeProject/chat_bot_with_langchain/.venv/lib/python3.10/site-packages/pandas/core/frame.py:11693, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11685 @doc(make_doc("mean", ndim=2))
#   11686 def mean(
#   11687     self,
#    (...)
#   11691     **kwargs,
#   11692 ):
# > 11693     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694     if isinstance(result, Series):
#   11695         result = result.__finalize__(self, method="mean")
#
# File ~/officeProject/chat_bot_with_langchain/.venv/lib/python3.10/site-packages/pandas/core/generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
# ...

# %%
happiness_report = pd.read_csv('data/world_happiness_report.csv')

# %%
happiness_report

# %%
df = pd.DataFrame(happiness_report)

# %%
df

# %%
df['Life Ladder'].describe()

# %%
df.count()

# %%
df.count(axis=0)

# %%
df.count(axis=1)

# %% [markdown]
# ### load json

# %%
json_loaded_data = pd.read_json('data/new_file2.json')

# %%
pd.DataFrame(json_loaded_data)

# %%
world_happiness_report = pd.read_csv('data/world_happiness_report.csv')

# %%
world_happiness_report

# %%
world_happiness_report = pd.DataFrame(world_happiness_report)

# %%
world_happiness_report.describe()

# %%
world_happiness_report.shape

# %%
world_happiness_report.dtypes

# %%
world_happiness_report.columns

# %%
# world_happiness_report2=pd.read_csv('data/world_happiness_report.csv',header=1)
# world_happiness_report2=pd.read_csv('data/world_happiness_report.csv',header=None)
world_happiness_report2 = pd.read_csv('data/world_happiness_report.csv', header=None)
# world_happiness_report2 = pd.read_csv('data/world_happiness_report.csv', skiprows=[0])
world_happiness_report2 = pd.DataFrame(world_happiness_report2)

# %%
world_happiness_report2

# %%
# world_happiness_report2 = pd.read_csv('data/world_happiness_report.csv', usecols=['Life Ladder'])
world_happiness_report2 = pd.read_csv('data/world_happiness_report.csv', usecols=[0, 3, 4])
pd.DataFrame(world_happiness_report2)

# %%
# world_happiness_report2 = pd.read_csv('data/world_happiness_report.csv', usecols=['Life Ladder'])
# world_happiness_report2 = pd.read_csv('data/world_happiness_report.csv', nrows=7)
world_happiness_report2 = pd.read_csv('data/world_happiness_report.csv', nrows=7, usecols=[0, 4, 6], verbose=True)
pd.DataFrame(world_happiness_report2)
# Out:
# Tokenization took: 0.01 ms
# Type conversion took: 0.15 ms
# Parser memory cleanup took: 0.00 ms
# /tmp/ipykernel_7371/1948642314.py:3: FutureWarning: The 'verbose' keyword in pd.read_csv is deprecated and will be removed in a future version.
#   world_happiness_report2 = pd.read_csv('data/world_happiness_report.csv', nrows=7, usecols=[0, 4, 6], verbose=True)
#   Country name  Social support  Freedom to make life choices
# 0  Afghanistan           0.451                         0.718
# 1  Afghanistan           0.552                         0.679
# 2  Afghanistan           0.539                         0.600
# 3  Afghanistan           0.521                         0.496
# 4  Afghanistan           0.521                         0.531
# 5  Afghanistan           0.484                         0.578
# 6  Afghanistan           0.526                         0.509

# %%
world_happiness_report2 = pd.read_csv('data/world_happiness_report.csv', dtype={'year': 'float64'})
pd.DataFrame(world_happiness_report2).dtypes
# Out:
# Country name                         object
# year                                float64
# Life Ladder                         float64
# Log GDP per capita                  float64
# Social support                      float64
# Healthy life expectancy at birth    float64
# Freedom to make life choices        float64
# Generosity                          float64
# Perceptions of corruption           float64
# Positive affect                     float64
# Negative affect                     float64
# dtype: object

# %%
world_happiness_report2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1949 entries, 0 to 1948
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      1949 non-null   object
#  1   year                              1949 non-null   float64
#  2   Life Ladder                       1949 non-null   float64
#  3   Log GDP per capita                1913 non-null   float64
#  4   Social support                    1936 non-null   float64
#  5   Healthy life expectancy at birth  1894 non-null   float64
#  6   Freedom to make life choices      1917 non-null   float64
#  7   Generosity                        1860 non-null   float64
#  8   Perceptions of corruption         1839 non-null   float64
#  9   Positive affect                   1927 non-null   float64
#  10  Negative affect                   1933 non-null   float64
# dtypes: float64(10), object(1)
# ...

# %%
country = world_happiness_report2['Country name']

# %%
country
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1944       Zimbabwe
# 1945       Zimbabwe
# 1946       Zimbabwe
# 1947       Zimbabwe
# 1948       Zimbabwe
# Name: Country name, Length: 1949, dtype: object

# %%
country.tail()
# Out:
# 1944    Zimbabwe
# 1945    Zimbabwe
# 1946    Zimbabwe
# 1947    Zimbabwe
# 1948    Zimbabwe
# Name: Country name, dtype: object

# %%
country.head()
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: Country name, dtype: object

# %%
x = world_happiness_report2[['Country name', 'Social support']]

# %%
x
# Out:
#      Country name  Social support
# 0     Afghanistan           0.451
# 1     Afghanistan           0.552
# 2     Afghanistan           0.539
# 3     Afghanistan           0.521
# 4     Afghanistan           0.521
# ...           ...             ...
# 1944     Zimbabwe           0.768
# 1945     Zimbabwe           0.754
# 1946     Zimbabwe           0.775
# 1947     Zimbabwe           0.759
# 1948     Zimbabwe           0.717
#
# [1949 rows x 2 columns]

# %%
x.tail()
# Out:
#      Country name  Social support
# 1944     Zimbabwe           0.768
# 1945     Zimbabwe           0.754
# 1946     Zimbabwe           0.775
# 1947     Zimbabwe           0.759
# 1948     Zimbabwe           0.717

# %%
x.head()
# Out:
#   Country name  Social support
# 0  Afghanistan           0.451
# 1  Afghanistan           0.552
# 2  Afghanistan           0.539
# 3  Afghanistan           0.521
# 4  Afghanistan           0.521

# %% [markdown]
# ### find the total number of rows and columns

# %%
x
# Out:
#      Country name  Social support
# 0     Afghanistan           0.451
# 1     Afghanistan           0.552
# 2     Afghanistan           0.539
# 3     Afghanistan           0.521
# 4     Afghanistan           0.521
# ...           ...             ...
# 1944     Zimbabwe           0.768
# 1945     Zimbabwe           0.754
# 1946     Zimbabwe           0.775
# 1947     Zimbabwe           0.759
# 1948     Zimbabwe           0.717
#
# [1949 rows x 2 columns]

# %%
world_happiness_report3 = pd.read_csv('data/world_happiness_report.csv')
# world_happiness_report3=pd.DataFrame(world_happiness_report3).dtypes
world_happiness_report3.shape
# Out:
# (1949, 11)

# %%
world_happiness_report3
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
world_happiness_report3.tail(n=10)
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 1939     Zimbabwe  2011        4.846               7.846           0.865
# 1940     Zimbabwe  2012        4.955               7.983           0.896
# 1941     Zimbabwe  2013        4.690               7.985           0.799
# 1942     Zimbabwe  2014        4.184               7.991           0.766
# 1943     Zimbabwe  2015        3.703               7.992           0.736
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 1939                             48.12                         0.633
# ...

# %% [markdown]
# ### difference between loc and iloc
# * iloc search for index number
# * loc search for index name

# %%
world_happiness_report3.loc[0]
# Out:
# Country name                        Afghanistan
# year                                       2008
# Life Ladder                               3.724
# Log GDP per capita                         7.37
# Social support                            0.451
# Healthy life expectancy at birth           50.8
# Freedom to make life choices              0.718
# Generosity                                0.168
# Perceptions of corruption                 0.882
# Positive affect                           0.518
# Negative affect                           0.258
# Name: 0, dtype: object

# %%
world_happiness_report3.iloc[0]
# Out:
# Country name                        Afghanistan
# year                                       2008
# Life Ladder                               3.724
# Log GDP per capita                         7.37
# Social support                            0.451
# Healthy life expectancy at birth           50.8
# Freedom to make life choices              0.718
# Generosity                                0.168
# Perceptions of corruption                 0.882
# Positive affect                           0.518
# Negative affect                           0.258
# Name: 0, dtype: object

# %%
world_happiness_report3.loc[:]
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
world_happiness_report3.iloc[:]
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
world_happiness_report3.loc[:4]
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724               7.370           0.451
# 1  Afghanistan  2009        4.402               7.540           0.552
# 2  Afghanistan  2010        4.758               7.647           0.539
# 3  Afghanistan  2011        3.832               7.620           0.521
# 4  Afghanistan  2012        3.783               7.705           0.521
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                             50.80                         0.718       0.168
# 1                             51.20                         0.679       0.190
# 2                             51.60                         0.600       0.121
# 3                             51.92                         0.496       0.162
# 4                             52.24                         0.531       0.236
#
#    Perceptions of corruption  Positive affect  Negative affect
# ...

# %%
world_happiness_report3.iloc[:4]
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724               7.370           0.451
# 1  Afghanistan  2009        4.402               7.540           0.552
# 2  Afghanistan  2010        4.758               7.647           0.539
# 3  Afghanistan  2011        3.832               7.620           0.521
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                             50.80                         0.718       0.168
# 1                             51.20                         0.679       0.190
# 2                             51.60                         0.600       0.121
# 3                             51.92                         0.496       0.162
#
#    Perceptions of corruption  Positive affect  Negative affect
# 0                      0.882            0.518            0.258
# 1                      0.850            0.584            0.237
# ...

# %% [markdown]
# ### data cleaning
# bad data
# * missing values
# * duplicates
# * inconsistent data format
# * wrong data

# %%
world_happiness_report4 = pd.read_csv('data/world_happiness_report.csv')

# %%
pd.isnull(world_happiness_report4)
# Out:
#       Country name   year  Life Ladder  Log GDP per capita  Social support  \
# 0            False  False        False               False           False
# 1            False  False        False               False           False
# 2            False  False        False               False           False
# 3            False  False        False               False           False
# 4            False  False        False               False           False
# ...            ...    ...          ...                 ...             ...
# 1944         False  False        False               False           False
# 1945         False  False        False               False           False
# 1946         False  False        False               False           False
# 1947         False  False        False               False           False
# 1948         False  False        False               False           False
#
# ...

# %%
import numpy as np

np.where(pd.isnull(world_happiness_report4))
# Out:
# (array([  25,   25,   25,   28,   28,   28,   29,   29,   29,   66,  110,
#          111,  112,  112,  112,  112,  112,  112,  113,  114,  115,  116,
#          117,  126,  135,  147,  218,  224,  263,  264,  275,  294,  342,
#          342,  342,  343,  343,  344,  345,  346,  347,  348,  349,  350,
#          350,  351,  351,  352,  352,  353,  354,  355,  356,  378,  423,
#          423,  423,  436,  436,  437,  449,  466,  466,  466,  498,  498,
#          499,  500,  509,  510,  511,  512,  542,  564,  606,  608,  636,
#          699,  700,  701,  702,  703,  704,  705,  706,  707,  708,  709,
#          709,  709,  710,  730,  732,  761,  765,  771,  771,  772,  772,
#          773,  773,  779,  779,  800,  815,  845,  851,  860,  860,  862,
#          864,  865,  866,  867,  868,  869,  870,  871,  872,  872,  872,
#          873,  873,  873,  874,  874,  874,  905,  906,  906,  906,  907,
#          908,  909,  910,  911,  912,  913,  914,  915,  916,  917,  918,
# ...

# %%
world_happiness_report4.iloc[25, 4]
# Out:
# nan

# %%
world_happiness_report4.iloc[25]
# Out:
# Country name                        Algeria
# year                                   2010
# Life Ladder                           5.464
# Log GDP per capita                    9.287
# Social support                          NaN
# Healthy life expectancy at birth       64.5
# Freedom to make life choices          0.593
# Generosity                           -0.205
# Perceptions of corruption             0.618
# Positive affect                         NaN
# Negative affect                         NaN
# Name: 25, dtype: object

# %%
good_data = world_happiness_report4.dropna()

# %%
good_data
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
bad_data = world_happiness_report4[~world_happiness_report4.index.isin(good_data.index)]

# %%
bad_data
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 25        Algeria  2010        5.464               9.287             NaN
# 28        Algeria  2014        6.355               9.335           0.818
# 29        Algeria  2016        5.341               9.362           0.749
# 66      Australia  2005        7.341              10.659           0.968
# 110       Bahrain  2012        5.027              10.716           0.911
# ...           ...   ...          ...                 ...             ...
# 1908        Yemen  2007        4.477               8.214           0.825
# 1916        Yemen  2016        3.826               7.715           0.775
# 1917        Yemen  2017        3.254               7.578           0.790
# 1918        Yemen  2018        3.058                 NaN           0.789
# 1919        Yemen  2019        4.197                 NaN           0.870
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
world_happiness_report4.dropna()
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
world_happiness_report4.dropna(inplace=True)

# %%
world_happiness_report4
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
world_happiness_report5 = pd.read_csv('data/world_happiness_report.csv')

# %%
world_happiness_report5
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
import numpy as np

# %%
np.where(pd.isnull(world_happiness_report5))
# Out:
# (array([  25,   25,   25,   28,   28,   28,   29,   29,   29,   66,  110,
#          111,  112,  112,  112,  112,  112,  112,  113,  114,  115,  116,
#          117,  126,  135,  147,  218,  224,  263,  264,  275,  294,  342,
#          342,  342,  343,  343,  344,  345,  346,  347,  348,  349,  350,
#          350,  351,  351,  352,  352,  353,  354,  355,  356,  378,  423,
#          423,  423,  436,  436,  437,  449,  466,  466,  466,  498,  498,
#          499,  500,  509,  510,  511,  512,  542,  564,  606,  608,  636,
#          699,  700,  701,  702,  703,  704,  705,  706,  707,  708,  709,
#          709,  709,  710,  730,  732,  761,  765,  771,  771,  772,  772,
#          773,  773,  779,  779,  800,  815,  845,  851,  860,  860,  862,
#          864,  865,  866,  867,  868,  869,  870,  871,  872,  872,  872,
#          873,  873,  873,  874,  874,  874,  905,  906,  906,  906,  907,
#          908,  909,  910,  911,  912,  913,  914,  915,  916,  917,  918,
# ...

# %%
world_happiness_report5.iloc[:, 0]
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1944       Zimbabwe
# 1945       Zimbabwe
# 1946       Zimbabwe
# 1947       Zimbabwe
# 1948       Zimbabwe
# Name: Country name, Length: 1949, dtype: object

# %%
world_happiness_report5.fillna(6000, inplace=True)

# %%
world_happiness_report5.dropna()
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
good_data = world_happiness_report5.dropna()

# %%
bad_data = world_happiness_report5[~world_happiness_report5.index.isin(good_data.index)]

# %%
bad_data
# Out:
# Empty DataFrame
# Columns: [Country name, year, Life Ladder, Log GDP per capita, Social support, Healthy life expectancy at birth, Freedom to make life choices, Generosity, Perceptions of corruption, Positive affect, Negative affect]
# Index: []

# %%
world_happiness_report6 = pd.read_csv('data/world_happiness_report.csv')

# %%
world_happiness_report6['Generosity'].fillna(7777, inplace=True)
# Out:
# /tmp/ipykernel_7371/2347594446.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   world_happiness_report6['Generosity'].fillna(7777,inplace=True)

# %%
world_happiness_report6['Generosity'].mean()
# Out:
# 355.13247408927657

# %%
world_happiness_report6['Generosity'].mode()
# Out:
# 0    7777.0
# Name: Generosity, dtype: float64

# %%
world_happiness_report6['Generosity'].mode()[0]
# Out:
# 7777.0

# %%
sales_data = pd.read_csv('data/sales_data.csv')

# %%
sales_data
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
good_data = sales_data.dropna()
bad_data = sales_data[~sales_data.index.isin(good_data.index)]

# %%
bad_data
# Out:
#                   Region          Country  Item Type Sales Channel  \
# 5  Australia and Oceania  Solomon Islands  Baby Food        Online
#
#   Order Priority Order Date   Order ID  Ship Date  Units Sold  Unit Price  \
# 5              C   2/4/2015  547995746  2/21/2015        2974         NaN
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 5     159.42      759202.72   474115.08     285087.64

# %%
sales_data.loc[5, 'Unit Price']
# Out:
# nan

# %%
world_happiness_report7 = pd.read_csv('data/world_happiness_report.csv')

# %%
world_happiness_report7
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
world_happiness_report7.groupby('Country name')['Life Ladder'].count()
# Out:
# Country name
# Afghanistan    12
# Albania        13
# Algeria         8
# Angola          4
# Argentina      15
#                ..
# Venezuela      15
# Vietnam        14
# Yemen          12
# Zambia         14
# Zimbabwe       15
# Name: Life Ladder, Length: 166, dtype: int64

# %%
world_happiness_report7.groupby('Country name').count()
# Out:
#               year  Life Ladder  Log GDP per capita  Social support  \
# Country name
# Afghanistan     12           12                  12              12
# Albania         13           13                  13              13
# Algeria          8            8                   8               7
# Angola           4            4                   4               4
# Argentina       15           15                  15              15
# ...            ...          ...                 ...             ...
# Venezuela       15           15                  12              15
# Vietnam         14           14                  14              13
# Yemen           12           12                  10              12
# Zambia          14           14                  14              14
# Zimbabwe        15           15                  15              15
#
#               Healthy life expectancy at birth  Freedom to make life choices  \
# Country name
# ...

# %%
sales_data2 = pd.read_csv('data/sales_data.csv')

# %%
sales_data2
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
sales_data2.groupby(['Region', 'Sales Channel'], as_index=False)['Country'].count()
# Out:
#                                Region Sales Channel  Country
# 0                                Asia       Offline        6
# 1                                Asia        Online        5
# 2               Australia and Oceania       Offline        4
# 3               Australia and Oceania        Online        7
# 4   Central America and the Caribbean       Offline        5
# 5   Central America and the Caribbean        Online        2
# 6                              Europe       Offline        9
# 7                              Europe        Online       13
# 8        Middle East and North Africa       Offline        2
# 9        Middle East and North Africa        Online        8
# 10                      North America       Offline        3
# 11                 Sub-Saharan Africa       Offline       21
# 12                 Sub-Saharan Africa        Online       15

# %% [markdown]
# ### pandas and sql and sqlalchemy

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+pymysql://root:password@localhost/northwind')

# %%
sql_data = pd.read_sql_table('Employees', engine)

# %%
sql_data
# Out:
#    EmployeeID   LastName FirstName                     Title TitleOfCourtesy  \
# 0           1    Davolio     Nancy      Sales Representative             Ms.
# 1           2     Fuller    Andrew     Vice President, Sales             Dr.
# 2           3  Leverling     Janet      Sales Representative             Ms.
# 3           4    Peacock  Margaret      Sales Representative            Mrs.
# 4           5   Buchanan    Steven             Sales Manager             Mr.
# 5           6     Suyama   Michael      Sales Representative             Mr.
# 6           7       King    Robert      Sales Representative             Mr.
# 7           8   Callahan     Laura  Inside Sales Coordinator             Ms.
# 8           9  Dodsworth      Anne      Sales Representative             Ms.
#
#    BirthDate   HireDate                           Address      City Region  \
# 0 1948-12-08 1992-05-01         507 - 20th Ave. E.Apt. 2A   Seattle     WA
# ...

# %%
sql_data = pd.read_sql_table('Employees', engine, columns=['LastName', 'FirstName'])

# %%
sql_data
# Out:
#     LastName FirstName
# 0    Davolio     Nancy
# 1     Fuller    Andrew
# 2  Leverling     Janet
# 3    Peacock  Margaret
# 4   Buchanan    Steven
# 5     Suyama   Michael
# 6       King    Robert
# 7   Callahan     Laura
# 8  Dodsworth      Anne

# %%
sql_data = pd.read_sql_table('Products', engine, columns=['ProductName', 'UnitPrice'])

# %%
sql_data
# Out:
#                       ProductName  UnitPrice
# 0                            Chai      18.00
# 1                           Chang      19.00
# 2                   Aniseed Syrup      10.00
# 3    Chef Anton's Cajun Seasoning      22.00
# 4          Chef Anton's Gumbo Mix      21.35
# ..                            ...        ...
# 72                      Rd Kaviar      15.00
# 73                  Longlife Tofu      10.00
# 74             Rhnbru Klosterbier       7.75
# 75                     Lakkalikri      18.00
# 76  Original Frankfurter grne Soe      13.00
#
# [77 rows x 2 columns]

# %%
sql_query = """select * from Products;"""
sql_data = pd.read_sql_query(sql_query, engine)

# %%
sql_data
# Out:
#     ProductID                    ProductName  SupplierID  CategoryID  \
# 0           1                           Chai           1           1
# 1           2                          Chang           1           1
# 2           3                  Aniseed Syrup           1           2
# 3           4   Chef Anton's Cajun Seasoning           2           2
# 4           5         Chef Anton's Gumbo Mix           2           2
# ..        ...                            ...         ...         ...
# 72         73                      Rd Kaviar          17           8
# 73         74                  Longlife Tofu           4           7
# 74         75             Rhnbru Klosterbier          12           1
# 75         76                     Lakkalikri          23           1
# 76         77  Original Frankfurter grne Soe          12           2
#
#         QuantityPerUnit  UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel  \
# ...

# %%
sql_query = """select * from Products where ProductName='Chai';"""
sql_data = pd.read_sql_query(sql_query, engine)

# %%
sql_data
# Out:
#    ProductID ProductName  SupplierID  CategoryID     QuantityPerUnit  \
# 0          1        Chai           1           1  10 boxes x 20 bags
#
#    UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel Discontinued
# 0       18.0            39             0            10      b'\x00'

# %%
sql_query = """select * from Products where ProductName='Chai';"""
sql_data = pd.read_sql(sql_query, engine)

# %%
sales_data
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
pd.read_sql('Products', engine)
# Out:
#     ProductID                    ProductName  SupplierID  CategoryID  \
# 0           1                           Chai           1           1
# 1           2                          Chang           1           1
# 2           3                  Aniseed Syrup           1           2
# 3           4   Chef Anton's Cajun Seasoning           2           2
# 4           5         Chef Anton's Gumbo Mix           2           2
# ..        ...                            ...         ...         ...
# 72         73                      Rd Kaviar          17           8
# 73         74                  Longlife Tofu           4           7
# 74         75             Rhnbru Klosterbier          12           1
# 75         76                     Lakkalikri          23           1
# 76         77  Original Frankfurter grne Soe          12           2
#
#         QuantityPerUnit  UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel  \
# ...

# %%
sql_data
# Out:
#     ProductID                    ProductName  SupplierID  CategoryID  \
# 0           1                           Chai           1           1
# 1           2                          Chang           1           1
# 2           3                  Aniseed Syrup           1           2
# 3           4   Chef Anton's Cajun Seasoning           2           2
# 4           5         Chef Anton's Gumbo Mix           2           2
# ..        ...                            ...         ...         ...
# 72         73                      Rd Kaviar          17           8
# 73         74                  Longlife Tofu           4           7
# 74         75             Rhnbru Klosterbier          12           1
# 75         76                     Lakkalikri          23           1
# 76         77  Original Frankfurter grne Soe          12           2
#
#         QuantityPerUnit  UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel  \
# ...
